# %% [markdown]
# Este archivo contiene el modelo inicial de clasificación para reptiles, actualmente hay 10 clases (chamaleon,crocodile_alligator, frog, gecko, iguana, lizard, salamander, snake, toad, turtle_tortoise). Y la división del dataset es en proporción 70 % para train, 20 % para validation y 10 % para test.

# %%
#Importaciones de librerías necesarias
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Cargar dataset como data_dir
rutas = []
labels = []
data_dir = r"C:\Users\rodri\OneDrive\Documentos\8vo\Dataset"

for carpeta in os.listdir(data_dir):
    for imagen in os.listdir(os.path.join(data_dir, carpeta)):
        rutas.append(os.path.join(data_dir, carpeta, imagen))
        labels.append(carpeta)
        
        
print("Número total de imágenes:", len(rutas))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[2], line 7
#       4 data_dir = r"C:\Users\rodri\OneDrive\Documentos\8vo\Dataset"
#       6 for carpeta in os.listdir(data_dir):
# ----> 7     for imagen in os.listdir(os.path.join(data_dir, carpeta)):
#       8         rutas.append(os.path.join(data_dir, carpeta, imagen))
#       9         labels.append(carpeta)
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:\\Users\\rodri\\OneDrive\\Documentos\\8vo\\Dataset\\main.ipynb'

# %%
# División en 70/20/10
train_dir = train_datagen.flow_from_directory(
    data_dir,
    validation_split=0.3,
    subset="training",
    seed=123,
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary'
)
    


val_dir = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=16
)

# Ahora dividimos el 30% en 20% y 10%
val_batches = tf.data.experimental.cardinality(val_dir)
test_size = val_batches // 3  

test_ds = val_dir.take(test_size)
val_dir = val_dir.skip(test_size)


train_generator = train_datagen.flow_from_directory(
							train_dir,
							target_size = (150, 150),
							batch_size = 1,
							class_mode ='binary',
							)
